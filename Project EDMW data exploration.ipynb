# %% [markdown]
# Import statements

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# Text extraction

# %%
data = requests.get("https://forums.hardwarezone.com.sg/eat-drink-man-woman-16/").text

# %%
soup = BeautifulSoup(data)

# %%
print(soup.get_text())
# Out:
# Eat-Drink-Man-Woman - www.hardwarezone.com.sg
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# /**
# * vBulletin 3.8.7 CSS
# * Style: 'HWZ 2016'; Style ID: 59
# */
# @import url("clientscript/vbulletin_css/style-a8af9f5c-00059.css");
#
#
#
#
#
#
# <!--
# var SESSIONURL = "s=787bd8a77b7a6a6c0b6284ba162f74c1&";
# var SECURITYTOKEN = "guest";
# var IMGDIR_MISC = "https://www.hardwarezone.com.sg/img/forums/hwz/misc";
# var vb_disable_ajax = parseInt("0", 10);
# // -->
#
#
#
#
#
#
#
#
#
#
#
#
# 	//<![CDATA[
# 		// Global parameters under HWZ namespace
# 		window.HWZ = {"accordion":{"enabled":false,"index":-1,"highlight":null},"layout":{"enabled":true,"width":"fixed"},"fonts":{"enabled":false,"size":"medium"}};
# 		HWZ.foruminfo = {"forum":{"id":16,"title":"Eat-Drink-Man-Woman","hierachytitle":"Lifestyle\/Eat-Drink-Man-Woman"},"thread":{"id":null,"title":null,"titleraw":""},"user":{"id":0,"name":"Unregistered"}};
# ...
